# %% [markdown]
# # 2 - Measuring Linear Association with the Correlation Function

# %% [markdown]
# Script for the 2-Measuring-Linear-Association-with-the-Correlation-Function.pdf

# %% [markdown]
# ## Review of Correlation

# %% [markdown]
# ### Girth, Height and Volume for Black Cherry Trees

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

trees = pd.read_csv('trees.csv')
trees = trees[['Girth','Height','Volume']] # ignore the index column
print(trees.shape)
trees.head()
# Out:
# (31, 3)
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
sns.pairplot(trees)
plt.show()

# %% [markdown]
# Grith is very strongly associated with volume.
# So Grith is really great predictor of volume in these trees.
#
# The hight of a tree is also a decent predictor, as the height increases so does the volume.

# %%
# Covariances
trees.cov()
# Out:
#             Girth     Height      Volume
# Girth    9.847914  10.383333   49.888118
# Height  10.383333  40.600000   62.660000
# Volume  49.888118  62.660000  270.202796

# %%
# Correlations
trees.corr()
# Out:
#            Girth   Height    Volume
# Girth   1.000000  0.51928  0.967119
# Height  0.519280  1.00000  0.598250
# Volume  0.967119  0.59825  1.000000

# %% [markdown]
# We wouldn’t have come to the conclusion that the Girth and Volume seems especially strong only looking at the covariances.
#
# When we look at the covariance we see values that take into account the unit involved.
#
# When we look at the correlation without worrying about the units
